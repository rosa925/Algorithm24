# %% [markdown]
# #### 1) 문제 정의 (MD)

# %% [markdown]
# 텍스트의 첫 번째 위치에 패턴을 놓고 비교한다. 이 과정을 패턴을 오른쪽으로 한 칸씩 옮기면서 성공한 매칭이 나타날 때까지 반복한다.

# %% [markdown]
# #### 2) 알고리즘 설명  (MD)

# %% [markdown]
# 텍스트 HELLO WORLD

# %% [markdown]
# 패 턴  LO

# %% [markdown]
# ##### 위 그림을 보면 패턴의 첫 번째 문자는 'L'인데 텍스트의 첫 번째 문자는 'H'로 서로 다르다.
# ##### 따라서 패턴의 다음 문자 'O'를 비교할 필요도 없이 입력의 다음 문자로 이동한다.
# ##### 이 과정을 패턴의 첫 번째 문자가 일치할 때까지 반복한다.
# ##### 4번째 위치에서 패턴의 모든 문자가 일치되었으므로, 이 위치가 반환된다.

# %% [markdown]
# ####  3) 손으로 푼 예제 (MD, 이미지 삽입)

# %% [markdown]
# ![예제 3-3 손으로 푼 예제.jpg](<attachment:예제 3-3 손으로 푼 예제.jpg>)

# %% [markdown]
# #### 4) 알고리즘 개요(입력 변수, 출력, 알고리즘 개요) (MD)

# %% [markdown]
# 1행 : 억지 기법 문자열 매칭 알고리즘이고 입력 문자열 T와 패턴 P가 입력

# %% [markdown]
# 4행 : 모든 가능한 패턴의 위치에 대한 범위(범위에 유의)

# %% [markdown]
# 6~9행 : 패턴의 문자들을 비교해 모두 일치(j==m)하면 위치를 반환

# %% [markdown]
# 10행 : 모두 일치하는 경우가 없으면 매칭 실패이고, -1을 반환

# %% [markdown]
# #### 5) 알고리즘 코드 (PY,C)

# %%
def string_matching(T, P):
    n = len(T)
    m = len(P)
    for i in range(n-m+1) :
        j = 0
    while j < m and P[j]==T[i+j] :
        j = j + 1
    if j == m :
        return i
    return -1

# %% [markdown]
# #### 6) 테스트 코드  (PY,C) , 입력을 바꾸어서

# %%
def string_matching(T, P):
    n = len(T)
    m = len(P)
    for i in range(n-m+1) :
        j = 0
    while j < m and P[j]==T[i+j] :
        j = j + 1
    if j == m :
        return i
    return -1

text = 'HELLO WORLD'
pattern = 'LO'
print(pattern, 'in', text, '-->', string_matching(text, pattern))
pattern = 'HI'
print(pattern, 'in', text, '-->', string_matching(text, pattern))
# Out:
# LO in HELLO WORLD --> -1
# HI in HELLO WORLD --> -1

# %% [markdown]
# #### 7) 수행 결과 (MD, 결과 캡춰하여 이미지로 삽입)

# %% [markdown]
# ![예제 3-3 결과화면.PNG](<attachment:예제 3-3 결과화면.PNG>)

# %% [markdown]
# #### 8) 복잡도 분석

# %% [markdown]
# ##### 이 알고리즘의 처리시간은 입력 텍스트와 패턴이 길수록 더 많은 시간이 걸릴 것이다. 따라서 입력의 크기는 텍스트의 길이 n과 패턴의 길이 m으로 두 가지이다.
# ##### 기본 연산은 문자의 비교 횟수가 가장 중요하므로 6행의 비교 연산이(P[j]==T[i+j])이 좋을 것이다.물론 7행을 선택해도 횟수는 동일하다.

# %% [markdown]
# #### 9) 조별 협력 내용 (상호 지도)

# %% [markdown]
# 각자 푸는 단계에 대해 이해를 못하는 부분이 있으면 실습시간에 서로 물어보면서 문제를 풀어나갔습니다.
