# %% [markdown]
# #### 1) 문제 정의 (MD)

# %% [markdown]
# 퀵 정렬 알고리즘

# %% [markdown]
# #### 2) 알고리즘 설명  (MD)

# %% [markdown]
# 순환구조를 이용하여 퀵 정렬 알고리즘을 다음과 같이 간략하게 기술할 수 있다. 입력 리스트인 A와 정렬 범위를 나타내는 left와 right가 매개변수로 전달된다.

# %% [markdown]
# ####  3) 손으로 푼 예제 (MD, 이미지 삽입)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 4) 알고리즘 개요(입력 변수, 출력, 알고리즘 개요) (MD)

# %% [markdown]
# ##### 함수명 : def quick_sort(A, left, right) -> A[left, right]를 오름차순으로 정렬
# ##### 입력변수 : A, left, right
# ##### 반환값 : 없음

# %% [markdown]
# #### 5) 알고리즘 코드 (PY,C)

# %%
def quick_sort(A, left, right):
    if left < right:
        pivot_index = partition(A, left, right)
        quick_sort(A, left, pivot_index - 1)
        quick_sort(A, pivot_index + 1, right)

# %% [markdown]
# #### 6) 테스트 코드  (PY,C) , 입력을 바꾸어서

# %%
def quick_sort(A, left, right):
    if left < right:
        pivot_index = partition(A, left, right)
        quick_sort(A, left, pivot_index - 1)
        quick_sort(A, pivot_index + 1, right)

data = [5, 3, 8, 4, 9, 1, 6, 2, 7]
print("Original:", data)
quick_sort(data, 0, len(data) - 1)
print("QuickSort:", data)
# Out:
# Original: [5, 3, 8, 4, 9, 1, 6, 2, 7]
# QuickSort: [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# #### 7) 수행 결과 (MD, 결과 캡춰하여 이미지로 삽입)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 8) 복잡도 분석

# %% [markdown]
# ##### 최선의 경우 : O(nlog2n)
# ##### 최악의 경우 : O(n^2)
# ##### 평균적인 경우 : O(nlog2n)

# %% [markdown]
# #### 9) 조별 협력 내용 (상호 지도)

# %% [markdown]
# 각자 푸는 단계에 대해 이해를 못하는 부분이 있으면 실습시간에 서로 물어보며 문제를 풀어나갔습니다.
