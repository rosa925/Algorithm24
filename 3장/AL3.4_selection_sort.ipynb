# %% [markdown]
# ### 1) 문제 정의 (MD)
# #### 가능한 모든 점의 쌍(pi,pj)에 대해 거리를 계산하고, 가장 짧은 것을 찾는다.

# %% [markdown]
# ### 2) 알고리즘 설명
# #### 이중 루프를 사용한다. 한번 계산한 점들의 쌍에 대해 다시 거리를 계산할 필요가 없기 때문에 내부 루프의 반복 범위를 잘 설정해야 한다. 점의 전체 개수에서를 받고, 최근접 거리를 초기화(무한대)한 후 외부 루프와 내부 루프 인덱스를 각각 i, j라 한다면 i < j를 만족하는 쌍 (pi,pj) 들만을 계산하면 된다.

# %% [markdown]
# ###   3) 손으로 푼 예제 (MD, 이미지 삽입)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###  4) 코드 개요(입력 변수, 출력, 알고리즘 개요) (MD)
# #### 1행 : 점의 리스트가 p가 입력된다. [ (x1,y1), ..., (xn, yn)]의 형태이다.
# #### 3행 : 일단 최근점 거리를 무한대라고 한다.
# #### 4~9행 : i < j를 만족하는 모든 쌍(pi, pj)에 대한 거리를 계산하고, mindist와 비교하여 이보다 작으면 mindist를 갱신한다.
# #### 9행 : 최종적으로 mindist에 최근접 쌍의 거리가 저장되어 있다.

# %% [markdown]
# ### 5) 알고리즘 코드 (PY,C)

# %%
def distance(p1, p2):
    return math.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)

def closet_pair(p):
    n=len(p)
    mindist=float(INF)
    for i in range(n-1):
        for j in range(i+1, n):
            dist=distance(p[i], p[j])
            if dist < mindist:
                mindist=dist
    return mindist

# %% [markdown]
# ### 6) 테스트 코드  (PY,C) , 입력을 바꾸어서

# %%
import math
import sys
INF = sys.maxsize

def distance(p1, p2):
    return math.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)

def closet_pair(p):
    n=len(p)
    mindist=float(INF)
    for i in range(n-1):
        for j in range(i+1, n):
            dist=distance(p[i], p[j])
            if dist < mindist:
                mindist=dist
    return mindist

p=[(2,3),(12,30),(40,50),(5,1),(12,10),(3,4)]
print("최근접 거리", closet_pair(p))
# Out:
# 최근접 거리 1.4142135623730951

# %% [markdown]
# ### 7) 수행 결과 (MD, 결과 캡춰하여 이미지로 삽입)
# #####

# %% [markdown]
# ![3.4.PNG](attachment:3.4.PNG)

# %% [markdown]
# ### 8) 복잡도 분석
# #### 입력의 크기는 전체 점의 수 n이고, 기본 연산은 6행의 유클리드 거리 계산 문장(distance(p[i], p[j]))이 좋을 것이다. 그리고 이 알고리즘의 효율은 입력의 구성과는 관련이 없이 최선, 평균, 최악의 경우에 대해 항상 동일하다.

# %% [markdown]
# ### 9) 조별 협력 내용 (상호 지도)

# %% [markdown]
# 각자 푸는 단계에 대해 이해를 못하는 부분이 있으면 실습시간에 서로 물어보면서 문제를 풀어나갔습니다.
